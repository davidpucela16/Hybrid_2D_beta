# %%
import numpy as np
import matplotlib.pyplot as plt

import os 
import pandas as pd
import pdb

import matplotlib.pyplot as plt

#Define Computer
Malphigui=0
if Malphigui:
    directory='/home/pdavid/Bureau/Updated_BCs_2/Code' #Malpighi
    directory_script='/home/pdavid/Bureau/Updated_BCs_2/Figures_and_Tests/Double_source_current_test'
else: #Auto_58
    directory='/home/pdavid/Bureau/Code/Updated_BCs_2/Code/'
    directory_script='/home/pdavid/Bureau/Code/Updated_BCs_2/Figures_and_Tests/Double_source_current_test'
    
    
os.chdir(directory)
csv_script=directory_script+'/csv_outputs'
from Testing import extract_COMSOL_data

COMSOL_lin_dir=directory_script + '/COMSOL_output/linear'
COMSOL_metab_dir=directory_script + '/COMSOL_output/metab'

array_of_cells=np.array([5,7,11,17,25])

# %%
Multi_q_linear=pd.read_fwf(csv_script + '/Multi_q_linear.csv')
Multi_q_metab=pd.read_fwf(csv_script + '/Multi_q_metab.csv')
q_FV_metab=pd.read_fwf(csv_script + '/q_FV_metab.csv')
q_FV_linear=pd.read_fwf(csv_script + '/q_FV_linear.csv')
q_Multi_linear=pd.read_fwf(csv_script + '/q_Multi_linear.csv')
phi_Multi_FEM_linear=pd.read_fwf(csv_script + '/phi_Multi_FEM_linear.csv')
phi_Multi_FEM_metab=pd.read_fwf(csv_script + '/phi_Multi_FEM_metab.csv')
err_phi_Multi_linear=pd.read_fwf(csv_script + '/err_phi_Multi_linear.csv')
err_phi_Multi_metab=pd.read_fwf(csv_script + '/err_phi_Multi_metab.csv')
err_phi_FV_linear=pd.read_fwf(csv_script + '/err_phi_FV_linear.csv')
err_q_Multi_linear=pd.read_fwf(csv_script + '/err_q_Multi_linear.csv')
err_q_Multi_metab=pd.read_fwf(csv_script + '/err_q_Multi_metab.csv')
err_q_FV_metab=pd.read_fwf(csv_script + '/err_q_FV_metab.csv')

# %%
plt.plot(array_of_cells, err_phi_Multi_linear, label='$\phi$-field linear')
plt.plot(array_of_cells,err_phi_Multi_metab , label='$\phi-field$ metab')
plt.plot(array_of_cells, err_phi_FV_linear, label='$\phi$ FV linear')
plt.plot(array_of_cells, err_q_Multi_linear, label='q Multi linear')
plt.plot(array_of_cells, err_q_FV_metab, label='q FV metab')
plt.plot(array_of_cells,err_q_FV_metab , label='err_q_FV_metab')

# %%
plt.plot(q_FEM_linear, label='q_FEM')
plt.plot(np.array(Multi_q_linear), label='q_Multi')
plt.legend()
plt.xlabel('source_ID')
plt.ylabel('q [$\mu mol \mu m^{-1} s^{-1}$]')
plt.title('Flux estimation linear model')
plt.show()

plt.plot(q_FEM_metab, label='q_FEM')
plt.plot(np.array(Multi_q_metab), label='q_Multi')
plt.legend()
plt.xlabel('source_ID')
plt.ylabel('q [$\mu mol \mu m^{-1} s^{-1}$]')
plt.title('Flux estimation non linear model')
plt.show()

# %%
plt.tricontourf(phi_Multi_cart_linear['x'], phi_Multi_cart_linear['y'], phi_Multi_cart_linear['phi'], levels=100)
plt.title('Contour Multi linear model')
plt.colorbar()
plt.show()

plt.tricontourf( FEM_x_linear/1e6, FEM_y_linear/1e6,FEM_phi_linear, levels=100)
plt.title('Contour FEM linear model')
plt.colorbar()
plt.show()

plt.tricontourf( FEM_x_linear/1e6, FEM_y_linear/1e6,FEM_phi_linear-phi_Multi_FEM_linear['phi'], levels=100)
plt.title('Absolute error model + reconstruction')
plt.colorbar()
plt.show()

# %%
plt.tricontourf(phi_Multi_cart_metab['x'], phi_Multi_cart_metab['y'], phi_Multi_cart_metab['phi'], levels=100)
plt.title('Contour Multi metab model')
plt.colorbar()
plt.show()

plt.tricontourf( FEM_x_metab/1e6, FEM_y_metab/1e6,FEM_phi_metab, levels=100)
plt.title('Contour FEM metab model')
plt.colorbar()
plt.show()

plt.tricontourf( FEM_x_metab/1e6, FEM_y_metab/1e6,FEM_phi_metab-phi_Multi_FEM_metab['phi'], levels=100)
plt.title('Absolute error model + reconstruction')
plt.colorbar()
plt.show()
